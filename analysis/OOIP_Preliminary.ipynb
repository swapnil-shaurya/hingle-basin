# %%
import numpy as np
import pandas as pd
from os.path import join, dirname, isfile, basename
from os import getcwd, listdir
import matplotlib.pyplot as plt

# %%
base_path = dirname(getcwd())
data_path = join(join(base_path, 'mapping'), 'all_data.csv')
all_data = pd.read_csv(data_path).filter(['easting', 'northing', 'oil saturation', 'porosity'])

# %%
all_data['OOIP'] = np.log10(all_data['oil saturation'] * all_data['porosity'] * 7758)

# %%
all_data.describe()
# Out:
#              easting       northing  oil saturation       porosity  \
# count  889249.000000  889249.000000   889249.000000  889249.000000
# mean    48200.000000   49703.418214        0.849492       0.050802
# std     27222.065192   28495.559763        0.088662       0.020348
# min      1100.000000     400.000000        0.662414       0.012773
# 25%     24600.000000   24999.370022        0.780344       0.036770
# 50%     48200.000000   49703.418214        0.849803       0.050097
# 75%     71800.000000   74407.466406        0.914378       0.066476
# max     95300.000000   99006.836428        1.000000       0.092802
#
#                 OOIP
# count  889249.000000
# mean        2.480168
# std         0.200124
# min         1.930151
# 25%         2.372433
# 50%         2.509005
# 75%         2.623113
# max         2.832468

# %%
plt.figure()
c = all_data['OOIP']
plt.scatter(all_data['easting'], all_data['northing'], c=c)
plt.show()
